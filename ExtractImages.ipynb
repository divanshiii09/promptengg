# %%
import requests
from bs4 import BeautifulSoup
from PIL import Image, UnidentifiedImageError
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from urllib.parse import urljoin
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
page_url = input("Enter a webpage URL: ")

# %%
try:
    response = requests.get(page_url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')

    images = soup.find_all('img')

    if not images:
        print("No images found on the page.")
    else:
        for i, img_tag in enumerate(images):
            img_src = img_tag.get('src')
            if not img_src:
                continue

            img_url = urljoin(page_url, img_src)

            if img_url.lower().endswith('.svg'):
                print(f"⏩ Skipping SVG: {img_url}")
                continue

            print(f"\n🖼️ Attempting to load image {i+1}: {img_url}")

            try:
                img_response = requests.get(img_url)
                img_response.raise_for_status()

                img = Image.open(BytesIO(img_response.content))
                width, height = img.size
                fmt = img.format

                plt.figure(figsize=(4, 4))
                plt.imshow(img)
                plt.axis('off')
                plt.title(f"Image {i+1}")
                plt.show()

                print("📄 Metadata:")
                print(f"🔗 URL     : {img_url}")
                print(f"📐 Size    : {width} x {height}")
                print(f"📦 Format  : {fmt}")
                print("-" * 50)

                shown += 1
                if shown >= 15:
                    break
            except (UnidentifiedImageError, Exception) as e:
                print(f"❌ Skipping image: {e}")
        if shown == 0:
            print("😕 No usable images could be loaded.")

except Exception as e:
    print(f"❌ Failed to fetch webpage: {e}")
# Out:
# 🖼️ Attempting to load image 1: https://en.wikipedia.org/static/images/icons/wikipedia.png
# 📄 Metadata:
# 🔗 URL     : https://en.wikipedia.org/static/images/icons/wikipedia.png
# 📐 Size    : 100 x 100
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
# ⏩ Skipping SVG: https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg
# ⏩ Skipping SVG: https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg
#
# 🖼️ Attempting to load image 4: https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png
# 📐 Size    : 20 x 20
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 5: https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Text_document_with_red_question_mark.svg/40px-Text_document_with_red_question_mark.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Text_document_with_red_question_mark.svg/40px-Text_document_with_red_question_mark.svg.png
# 📐 Size    : 40 x 40
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 6: https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Rosa_rubiginosa_1.jpg/250px-Rosa_rubiginosa_1.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Rosa_rubiginosa_1.jpg/250px-Rosa_rubiginosa_1.jpg
# 📐 Size    : 250 x 232
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 7: https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Rosa_Precious_platinum.jpg/250px-Rosa_Precious_platinum.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Rosa_Precious_platinum.jpg/250px-Rosa_Precious_platinum.jpg
# 📐 Size    : 250 x 175
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 8: https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/20px-OOjs_UI_icon_edit-ltr.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/20px-OOjs_UI_icon_edit-ltr.svg.png
# 📐 Size    : 20 x 20
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 9: https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Rose_Prickles.jpg/250px-Rose_Prickles.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Rose_Prickles.jpg/250px-Rose_Prickles.jpg
# 📐 Size    : 250 x 378
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 10: https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Roseleaves3800px.JPG/500px-Roseleaves3800px.JPG
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Roseleaves3800px.JPG/500px-Roseleaves3800px.JPG
# 📐 Size    : 500 x 335
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image
jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Codex_Manesse_Rudolf_von_Neuenburg.jpg/250px-Codex_Manesse_Rudolf_von_Neuenburg.jpg
# 📐 Size    : 250 x 381
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 24: https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Maria_Amelia_of_Braganza.jpg/250px-Maria_Amelia_of_Braganza.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Maria_Amelia_of_Braganza.jpg/250px-Maria_Amelia_of_Braganza.jpg
# 📐 Size    : 250 x 313
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 25: https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/The_Roses_of_Heliogabalus.jpg/250px-The_Roses_of_Heliogabalus.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/The_Roses_of_Heliogabalus.jpg/250px-The_Roses_of_Heliogabalus.jpg
# 📐 Size    : 250 x 154
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 26: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Et-Viljandi_coa.svg/250px-Et-Viljandi_coa.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Et-Viljandi_coa.svg/250px-Et-Viljandi_coa.svg.png
# 📐 Size    : 250 x 289
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 27: https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Tudor_Rose.svg/250px-Tudor_Rose.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Tudor_Rose.svg/250px-Tudor_Rose.svg.png
# 📐 Size    : 250 x 250
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 28: https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Imperial_Order_of_the_Rose_%28Brazil%29_-_Fram_Museum.jpg/250px-Imperial_Order_of_the_Rose_%28Brazil%29_-_Fram_Museum.jpg
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Imperial_Order_of_the_Rose_%28Brazil%29_-_Fram_Museum.jpg/250px-Imperial_Order_of_the_Rose_%28Brazil%29_-_Fram_Museum.jpg
# 📐 Size    : 250 x 333
# 📦 Format  : JPEG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 29: https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/40px-Commons-logo.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/40px-Commons-logo.svg.png
# 📐 Size    : 40 x 54
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 30: https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Wikispecies-logo.svg/40px-Wikispecies-logo.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Wikispecies-logo.svg/40px-Wikispecies-logo.svg.png
# 📐 Size    : 40 x 47
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 31: https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/40px-Wikiquote-logo.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/40px-Wikiquote-logo.svg.png
# 📐 Size    : 40 x 48
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 32: https://upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/20px-Symbol_category_class.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/20px-Symbol_category_class.svg.png
# 📐 Size    : 20 x 21
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 33: https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Saint_Lucia.svg/20px-Flag_of_Saint_Lucia.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Saint_Lucia.svg/20px-Flag_of_Saint_Lucia.svg.png
# 📐 Size    : 20 x 10
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 34: https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Coat_of_arms_of_Saint_Lucia.svg/40px-Coat_of_arms_of_Saint_Lucia.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Coat_of_arms_of_Saint_Lucia.svg/40px-Coat_of_arms_of_Saint_Lucia.svg.png
# 📐 Size    : 40 x 37
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 35: https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png
# 📄 Metadata:
# 🔗 URL     : https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png
# 📐 Size    : 20 x 20
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
#
# 🖼️ Attempting to load image 36: https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1&usesul3=1
# 📄 Metadata:
# 🔗 URL     : https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1&usesul3=1
# 📐 Size    : 1 x 1
# 📦 Format  : PNG
# --------------------------------------------------
# ❌ Skipping image: name 'shown' is not defined
# ⏩ Skipping SVG: https://en.wikipedia.org/static/images/footer/wikimedia.svg
# ⏩ Skipping SVG: https://en.wikipedia.org/w/resources/assets/mediawiki_compact.svg
# ❌ Failed to fetch webpage: name 'shown' is not defined
